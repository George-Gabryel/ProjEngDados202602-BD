# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
mongo_uri = os.getenv("MONGO_URI2")

client = MongoClient(mongo_uri, server_api=ServerApi('1'))

db = client['IBGE']

print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, server_api=<pymongo.server_api.ServerApi object at 0x75756c89a210>), 'IBGE')

# %%
data = db['PNADC']

# %%
serie = data[0]['resultado'][0]["serie"][0]["serie"]

# %%
print(serie)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, server_api=<pymongo.server_api.ServerApi object at 0x75756c89a210>), 'IBGE'), 'PNDAC.0.resultado.0.serie.0.serie')

# %%
import panda as pd

df = pd.DataFrame.from_dict(serie, orient='idenx', colums = )
