# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
mongo_uri = os.getenv("MONGO_URI2")

client = MongoClient(mongo_uri, server_api=ServerApi('1'))

db = client['IBGE']

print(db)
# Out:
# Database(MongoClient(host=['ac-gwyad75-shard-00-01.qmyziy5.mongodb.net:27017', 'ac-gwyad75-shard-00-00.qmyziy5.mongodb.net:27017', 'ac-gwyad75-shard-00-02.qmyziy5.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-srelw2-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x74d101215be0>), 'IBGE')

# %%
data = db['PNDAC']
